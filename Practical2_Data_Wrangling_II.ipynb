# %% [markdown]
# # Practical 2: Data Wrangling II
# Academic Performance Dataset

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create Synthetic Academic Dataset

# %%
data = {
    'Name': ['A','B','C','D','E','F','G','H','I','J'],
    'Math': [80, 90, np.nan, 70, 60, 85, 95, 100, 40, 55],
    'Science': [78, 88, 92, np.nan, 65, 80, 90, 105, 45, 50],
    'English': [85, 75, 80, 70, np.nan, 90, 95, 85, 60, 65]
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ## Check Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# ## Handle Missing Values (Fill with Mean)

# %%
df['Math'].fillna(df['Math'].mean(), inplace=True)
df['Science'].fillna(df['Science'].mean(), inplace=True)
df['English'].fillna(df['English'].mean(), inplace=True)
df

# %% [markdown]
# ## Detect Outliers using Boxplot

# %%
df[['Math','Science','English']].boxplot()
plt.show()

# %% [markdown]
# ## Handle Outliers (Capping values)

# %%
df['Science'] = np.where(df['Science'] > 100, 100, df['Science'])
df

# %% [markdown]
# ## Data Transformation (Log Transformation)

# %%
df['Math_log'] = np.log(df['Math'])
df[['Math','Math_log']]
