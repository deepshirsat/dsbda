# %%
### Observations:

1. Females have higher survival rates across most age groups.
2. Younger passengers had a slightly higher survival chance.
3. Male passengers show lower survival, especially adults.
4. There are some outliers in age (very old passengers).
5. Survival is influenced by both gender and age.

# %%
## Step 1: Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Step 2: Load Dataset

# %%
df = sns.load_dataset('iris')
df.head()

# %%
## Step 3: Dataset Information

# %%
df.info()
df.describe()

# %%
## Step 4: List Features and Types

# %%
for col in df.columns:
    print(col, ":", df[col].dtype)

# %%
## Step 5: Histograms for Feature Distribution

# %%
df.hist()
plt.suptitle("Feature Distributions (Histograms)")
plt.show()

# %%
## Step 6: Boxplots for Each Feature

# %%
for col in df.columns[:-1]:  # exclude species
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()
